# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\liewm\Documents\BT4222 Mining Web Data\Project\hotel.csv')
#df=df.drop(columns=['Unnamed: 0'])
df.head(2)
# Out:
#    Unnamed: 0  Average_Score   Hotel_Name Reviewer_Nationality  \
# 0           0            7.7  Hotel Arena              Russia
# 1           1            7.7  Hotel Arena             Ireland
#
#                                      Negative_Review  \
# 0   I am so angry that i made this post available...
# 1                                        No Negative
#
#                                      Positive_Review  Reviewer_Score  \
# 0   Only the park outside of the hotel was beauti...             2.9
# 1   No real complaints the hotel was great great ...             7.5
#
#                                                 Tags        lat       lng  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...  52.360576  4.915968
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...  52.360576  4.915968
#
#                                          cleaned_pos  \
# 0                               park hotel beautiful
# 1  real complaint hotel great great location surr...
#
# ...

# %% [markdown]
# ### 2.8 Negative Word Cloud

# %%
#load all the negative reviews into the word cloud 
df['cleaned_neg']=df["cleaned_neg"].fillna('')
text = " ".join(str(review) for review in df.cleaned_neg)
#using the stopwords available in python 
stopwords = set(STOPWORDS)
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# hello this is separation
